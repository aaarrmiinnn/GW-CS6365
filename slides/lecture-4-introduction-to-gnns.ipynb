# %% [markdown]
# <left><img width=25% src="img/gw_monogram_2c.png"></left>
#
# # Lecture 6: Introduction to Graph Neural Networks
#
# ### CS4907/CS6365 Machine Learning
#
# __Sardar Hamidian__<br>The George Washington Universiry
#
# __Armin Mehrabian__<br>The George Washington Universiry

# %% [markdown]
# # Recap: Shallow Encoders
#
# ## Limitations of shallow embedding methods:

# %% [markdown]
# - **$O(|V|)$ parameters are needed**:
#     - No sharing of parameters between nodes
#     - Every node has its own unique embedding

# %% [markdown]
# - **Inherently "transductive"**:
#     - Cannot generate embeddings for nodes that are not seen during training

# %% [markdown]
# - **Do not incorporate node features**:
#     - Many graphs have features that we can and should leverage

# %% [markdown]
# # Deep Graph Encoders
#
# - **Today**: We will now discuss deep methods based on graph neural networks (GNNs):
#
# $$ \text{ENC}(v) = \text{multiple layers of non-linear transformations based on graph structure} $$
#
# - **Note**: All these deep encoders can be combined with node similarity functions defined in Lecture 4.

# %% [markdown]
# # Deep Graph Encoders
#
# - **Deep graph encoders** utilize graph neural networks (GNNs) to learn node embeddings by performing multiple layers of non-linear transformations based on the graph structure.
#
# ![Deep Graph Encoders Image](./img/deep_graph_encoders.png)

# %% [markdown]
# - **Key Advantages**:
#     - Can generalize to unseen nodes (inductive)
#     - Share parameters across the graph, reducing complexity
#     - Can incorporate node features and graph structure effectively

# %% [markdown]
# - **Applications**:
#     - Node classification
#     - Link prediction
#     - Community Detection
#     - Graph-level tasks (e.g., molecular graph classification)

# %% [markdown]
# # Agenda
# # Local Network Neighborhoods
#
# - Describe aggregation strategies
# - Define computation graphs
#
# # Stacking Multiple Layers
#
# - Describe the model, parameters, and training
# - How to fit the model
# - Simple example for unsupervised and supervised training

# %% [markdown]
# # Setup
#
# - **Assume we have a graph $G$:**
#     - $V$ is the **vertex set**
#     - $A$ is the **adjacency matrix** (assume binary)
#     - $X \in \mathbb{R}^{m \times |V|}$ is a matrix of **node features**
#     - $v$: a node in $V$; $N(v)$: the set of neighbors of $v$
#
# - **Node features**:
#     - **Social networks**: User profile, User image
#     - **Biological networks**: Gene expression profiles, gene functional information
#     - **When there is no node feature in the graph dataset**:
#         - Indicator vectors (one-hot encoding of a node)
#         - Vector of constant 1: $[1, 1, 1, ..., 1]$

# %% [markdown]
# # A Naïve Approach
#
# - **Join adjacency matrix and features**
# - **Feed them into a deep neural net**:
#
# ![Naïve Approach Image](./img/gnn_to_dnn.png)
#
# ### Issues with this idea:
#
# - **$O(|V|)$ parameters**
# - **Not applicable to graphs of different sizes**
# - **Sensitive to node ordering**

# %% [markdown]
# # Inspiration from CNNs
#
# ![CNN Analogy](./img/cnn_analogy.png)
#
# - Goal is to generalize convolutions beyond simple lattices Leverage node features/attributes (e.g., text, images)

# %% [markdown]
# # However in Graph World
#
# ![Sliding Window in Graphs](./img/graph_sliding_window.png)
#
# - There is no fixed notion of locality or sliding window on the graph
# - Graph is permutation invariant

# %% [markdown]
# # From Images to Graphs
#
# - **Single Convolutional Neural Network (CNN) layer with 3x3 filter:**
#
# ![CNNs vs Graphs](./img/cnn_vs_graphs.png)
#
# ### Idea: Transform information at the neighbors and combine it:
# - Transform "messages" $h_i$ from neighbors: $W_i h_i$
# - Add them up: $\sum_i W_i h_i$

# %% [markdown]
# # Graph Neural Networks
#
# ### Idea: Node's neighborhood defines a computation graph
#
# - **Determine node computation graph**
# - **Propagate and transform information**
# ![Graph Convolutional Networks Image](./img/propagate_and_aggregate.png)
#
# ### Learn how to propagate information across the graph to compute node features.

# %% [markdown]
# # Idea: Aggregate Neighbors
#
# - Key idea: Generate node embeddings based on local network neighborhoods
#
# ![GNN Idea 1](./img/gnn_idea_1.png)

# %% [markdown]
# - Intuition: Network neighborhood defines a computation graph
# - Every node defines a computa2on graph based on its neighborhood!
#
# ![GNN Idea 3](./img/gnn_idea_3.png)

# %% [markdown]
# # Deep Model: Many Layers
#
# - Model can be of arbitrary depth:
#     - Nodes have embeddings at each layer
#     - Layer-0 embedding of node $𝑣$ is its input feature, $𝑥_𝑣$
#     - Layer-𝑘 embedding gets information from nodes that are $𝑘$ hops away
#
# ![GNN Idea 4](./img/gnn_idea_4.png)

# %% [markdown]
# # Neighborhood Aggregation
#
# - **Neighborhood aggregation:** Key distinctions are in how different approaches aggregate information across the layers
#
# ![GNN Idea 5](./img/gnn_idea_5.png)

# %% [markdown]
# # Neighborhood Aggregation
#
# - **Basic approach:** Average information from neighbors and apply a neural network
#
# ![GNN Idea 6](./img/gnn_idea_6.png)

# %% [markdown]
# # The Math: Deep Encoder
#
# - **Basic approach**: Average neighbor messages and apply a neural network
#
# $$ h_v^0 = x_v $$
#
# $$ h_v^{(l+1)} = \sigma\left(W_l \sum_{u \in N(v)} \frac{h_u^{(l)}}{|N(v)|} + B_l h_v^{(l)}\right), \forall l \in \{0, \dots, L-1\} $$
#
# $$ z_v = h_v^{(L)} $$

# %% [markdown]
# # Neighborhood Aggregation
#
# - **Basic approach:** Average information from neighbors and apply a neural network
#
# ![GNN Idea 7](./img/gnn_idea_7.png)

# %% [markdown]
# # The Math: Deep Encoder
#
#
# - **Basic approach**: Average neighbor messages and apply a neural network
#
# $$ h_v^{(0)} = x_v $$
#
# $$ h_v^{(k+1)} = \sigma\left(W_k \sum_{u \in N(v)} \frac{h_u^{(k)}}{|N(v)|} + B_k h_v^{(k)}\right), \forall k \in \{0, \dots, K-1\} $$
#
# $$ z_v = h_v^{(K)} $$
#
# - **$W_k$ and $B_k$** are the trainable weight matrices (i.e., what we learn).
# - **$z_v$** is the final node embedding.

# %% [markdown]
# # Matrix Formulation (1)
#
# - **Many aggregations can be performed efficiently by (sparse) matrix operations:**
#
# $$ H^{(l)} = \left[ h_1^{(l)} \, \dots \, h_{|V|}^{(l)} \right]^T $$
#
# - **What is $H^{(l)}$?**
#   - $H^{(l)}$ is a matrix of node embeddings at layer $l$.
#   - Each row $h_v^{(l)}$ represents the hidden embedding (or feature vector) of node $v$ at layer $l$.
#   - The dimensions of $H^{(l)}$ are $|V| \times d$, where $|V|$ is the number of nodes and $d$ is the embedding dimension.
#   - These embeddings capture information about the node and its neighbors.

# %% [markdown]
# - Then:
#
# $$ \sum_{u \in N(v)} h_u^{(l)} = A_{v,:} H^{(l)} $$
#
# - **What is $D$?**
#   - $D$ is a diagonal degree matrix where the diagonal entry $D_{v,v}$ is the degree of node $v$, i.e., $\text{Deg}(v) = |N(v)|$.
#   - The inverse of $D$, $D^{-1}$, is also diagonal, where $D^{-1}_{v,v} = \frac{1}{|N(v)|}$.
#   - This matrix normalizes the node embeddings by scaling contributions from neighbors based on node degree.

# %% [markdown]
# - **Therefore:**
#
# $$ \sum_{u \in N(v)} \frac{h_u^{(l-1)}}{|N(v)|} \longrightarrow H^{(l+1)} = D^{-1} A H^{(l)} $$
#
# - This formula expresses how node embeddings from neighbors are aggregated using sparse matrix multiplication with the adjacency matrix $A$ and normalized by $D^{-1}$.

# %% [markdown]
# # Matrix Formulation (2)
#
# - **Re-writing the update function in matrix form:**
#
# $$ H^{(l+1)} = \sigma\left(\tilde{A} H^{(l)} W_l^T + H^{(l)} B_l^T \right) $$

# %% [markdown]
#   where:
#
# $$ \tilde{A} = D^{-1} A $$
#
# - **Explanation**:
#   - **Neighborhood aggregation**: The term $( \tilde{A} H^{(l)} W_l^T $) aggregates information from the neighbors using the normalized adjacency matrix $( \tilde{A} )$.
#   - **Self-transformation**: The term $( H^{(l)} B_l^T $) applies a transformation to the node itself without aggregation from its neighbors.

# %% [markdown]
# - **In practice**, this implies that efficient sparse matrix multiplication can be used (since $( \tilde{A} $) is sparse).
#
# - **Note**: Not all GNNs can be expressed in matrix form, especially when the aggregation function is more complex.

# %% [markdown]
# # How to train a GNN
#
# - **Node embedding $z_v$** is a function of the input graph.
#
# - **Supervised setting**: we want to minimize the loss $\mathcal{L}$:
#
# $$ \min_{\Theta} \mathcal{L}(y, f(z_v)) $$
#
#   - $y$: node label
#   - $\mathcal{L}$ could be L2 if $y$ is a real number, or cross-entropy if $y$ is categorical.
#
# - **Unsupervised setting**:
#   - No node label available.
#   - Use the graph structure as the supervision!

# %% [markdown]
# # Unsupervised Training
#
# ### "Similar" nodes have similar embeddings
#
# $$ \mathcal{L} = \sum_{z_u, z_v} \text{CE}(y_{u,v}, \text{DEC}(z_u, z_v)) $$
#
# - Where $y_{u,v} = 1$ when node $u$ and $v$ are **similar**.
# - **CE** is the cross entropy.
# - **DEC** is the decoder, such as inner product (lecture 4).
#
# - **Node similarity** can be anything from lecture 3, e.g., a loss based on:
#   - **Random walks** (node2vec, DeepWalk, struc2vec).
#   - **Matrix factorization**.
#   - **Node proximity** in the graph.

# %% [markdown]
# # Supervised Training
#
# - **Directly train** the model for a supervised task (e.g., **node classification**).
# - Use cross-entropy loss:
#
# $$ \mathcal{L} = \sum_{v \in V} \left[ y_v \log(\sigma(z_v^T \Theta)) + (1 - y_v) \log(1 - \sigma(z_v^T \Theta)) \right] $$
#
# - **Explanation**:
#   - $z_v$: Encoder output, i.e., the node embedding for node $v$.
#   - $y_v$: The node class label (1 if the node belongs to a certain class, 0 otherwise).
#   - $\Theta$: Classification weights applied to the node embedding.
#   - $\sigma$: Sigmoid function, producing the probability that the node belongs to the class.
#
# - Example: Safe or toxic drug? The node embedding represents a drug, and the classification determines the outcome (safe/toxic).

# %% [markdown]
# # Training Overview
#
# ![GNN Design Overview 1 2](./img/gnn_design_1_2.png)

# %% [markdown]
# # Training Overview
#
# ![GNN Design Overview 3](./img/gnn_design_3.png)

# %% [markdown]
# # Training Overview
#
# ![GNN Design Overview 4](./img/gnn_design_4.png)

# %% [markdown]
# The same aggregation parameters are shared for all nodes:
# - The number of model parameters is sublinear in $|𝑉|$ and we can generalize to unseen nodes!
#
# ![GNN Shared parameters](./img/gnn_shared_params.png)

# %% [markdown]
# ![Inductive Embedding](./img/inductive_node_embedding.png)
#
# - Inductive node embedding Generalize to entirely unseen graphs
# - E.g., train on protein interaction graph from model organism A and generate embeddings on newly collected data about organism B

# %% [markdown]
# ![Inductive Embedding](./img/dynamic_graph_node_embedding.png)
# - Many application settings constantly encounter previously unseen nodes:
#     - E.g., Reddit, YouTube, Google Scholar
# - Need to generate new embeddings on demand

# %% [markdown]
# # Summary
#
# - **Recap**: Generate node embeddings by aggregating neighborhood information.
#   - We saw a **basic variant** of this idea.
#   - Key distinctions are in how different approaches aggregate information across the layers.
#
# - **Next**: Describe GraphSAGE graph neural network architecture.

# %% [markdown]
# <left><img width=25% src="img/gw_monogram_2c.png"></left>
#
# # Part 2: General Deep Graph Neural Neworks

# %% [markdown]
# # GNN Layer = Message + Aggregation
#
# - **Key components of a GNN layer**:
#   - (1) **Message**: Pass information from neighboring nodes.
#   - (2) **Aggregation**: Combine messages from neighbors to update node embeddings.
#
# - Different instantiations under this perspective:
#   - Examples include **GCN**, **GraphSAGE**, **GAT**, and others.
#
# ![General GNN Framework](./img/general_gnn_1.png)

# %% [markdown]
# # Design Considerations For GNNs

# %% [markdown]
# 1. #### How to design a single layer? (What kind of message aggregations and transrformations)

# %% [markdown]
# - **Message Aggregation**:
#     - Decide how information from neighboring nodes should be aggregated.
#     - Common methods include sum, mean, or max-pooling of neighboring node features.

# %% [markdown]
# - **Message Transformation**:
#     - Apply transformations (often linear or neural network layers) to the aggregated messages.
#     - Enables more expressive power in combining information from neighbors.

# %% [markdown]
# - **Normalization**:
#     - Choose if and how to normalize aggregated information (e.g., dividing by the degree of each node).
#     - Helps stabilize training and prevents over-smoothing of node embeddings.

# %% [markdown]
# - **Non-linearity**:
#     - Introduce non-linear activation functions after transformation.
#     - Allows the model to learn complex patterns and interactions in the graph data.

# %% [markdown]
# 2. #### How to stack different layers of a GNN?

# %% [markdown]
# - **Sequential Stacking**:
#     - Stack layers one after the other, passing the output of each layer to the next.
#     - Enables information to propagate across multiple hops in the graph.

# %% [markdown]
# - **Skip Connections**:
#     - Allow the model to access information from earlier layers directly.
#     - Reduces risk of information loss and helps with gradient flow in deeper networks.

# %% [markdown]
# - **Attention Mechanisms**:
#     - Use attention to weigh messages from different neighbors differently.
#     - Allows the GNN to focus on more relevant neighbors for each node.

# %% [markdown]
# - **Residual or Dense Connections**:
#     - Introduce connections that maintain information from prior layers.
#     - Improves training stability and supports deeper architectures.

# %% [markdown]
# 3. #### Should input always be the raw untouched graphs?

# %% [markdown]
# - **Raw Graph Structure**:
#     - Using the original graph structure ensures authentic relationships and dependencies are captured.

# %% [markdown]
# - **Structural Augmentation**:
#     - Add synthetic edges, prune less relevant edges, or incorporate virtual nodes.
#     - Enhances important relationships or reduces noise in the graph.

# %% [markdown]
# - **Feature Augmentation**:
#     - Add engineered node or edge features.
#     - Can improve model performance by providing more relevant patterns for learning.

# %% [markdown]
# - **Graph Sampling or Clustering**:
#     - Apply sampling or clustering to reduce graph size for large graphs.
#     - Keeps computations manageable while preserving local structure.

# %% [markdown]
# 4. #### How to train the GNN?

# %% [markdown]
# - **Supervised Learning**:
#     - Train with labeled data (e.g., node or edge labels).
#     - Use cross-entropy for classification or mean-squared error for regression.

# %% [markdown]
# - **Unsupervised Learning**:
#     - Use node similarity, graph reconstruction, or contrastive learning for unlabeled data.
#     - Captures the underlying graph structure without explicit labels.

# %% [markdown]
# - **Semi-supervised Learning**:
#     - Use both labeled and unlabeled data to generalize better.
#     - The GNN can learn from labeled nodes while leveraging unlabeled nodes for structural insights.

# %% [markdown]
# - **Loss Function Selection**:
#     - Choose an appropriate loss function for the task.
#     - Examples: cross-entropy for classification, contrastive loss for unsupervised training, or custom graph-structured losses.

# %% [markdown]
# <left><img width=25% src="img/gw_monogram_2c.png"></left>
#
# # Part 3: How to Design a Single Layer

# %% [markdown]
# # GNN Layer = Message + Aggregation
#
# - **Key components of a GNN layer**:
#   - (1) **Message**: Pass information from neighboring nodes.
#   - (2) **Aggregation**: Combine messages from neighbors to update node embeddings.
#
#
# ![General GNN Framework](./img/general_gnn_1.png)

# %% [markdown]
# ### A GNN Layer:
# - Compress a set of vectors into a single vector
# - Two-step process:
#     1. Message
#     2. Aggregation
#
# ![General GNN Framework](./img/general_gnn_2.png)

# %% [markdown]
# # Message Computation
#
# ## 1. Message Computation
#
# ![gnn_message_computation](./img/gnn_message_computation.png)
#
# - **Message Function**:
#     - The message function generates a message from each node, which will later be sent to neighboring nodes.
#     - **Equation**: $ \mathbf{m}_u^{(l)} = \text{MSG}^{(l)}\left( \mathbf{h}_u^{(l-1)} \right) $
# - **Intuition**:
#     - Each node creates a message, representing its current state, that will be shared with neighboring nodes in the graph.
# - **Example**:
#     - A linear transformation layer can serve as a message function.
#     - **Equation**: $ \mathbf{m}_u^{(l)} = \mathbf{W}^{(l)} \mathbf{h}_u^{(l-1)} $
#     - This involves multiplying the node’s features by a learnable weight matrix $\mathbf{W}^{(l)}$ to compute the message.

# %% [markdown]
# # Message Aggregation
#
# ## 2. Aggregation
#
# ![gnn_message_aggregation](./img/gnn_message_aggregation.png)
#
#
# - **Intuition**:
#     - Each node aggregates the messages received from its neighboring nodes to update its own representation.
#     - **Equation**: $ \mathbf{h}_v^{(l)} = \text{AGG}^{(l)}\left( \left\{ \mathbf{m}_u^{(l)}, u \in N(v) \right\} \right) $
# - **Example**:
#     - Common aggregators include sum, mean, or max functions, which combine the messages in different ways.
#     - **Equation**: $ \mathbf{h}_v^{(l)} = \text{Sum}\left(\left\{ \mathbf{m}_u^{(l)}, u \in N(v) \right\}\right) $
#     - The aggregation step can vary depending on the architecture; it controls how much influence each neighbor has on the target node.

# %% [markdown]
# # Issue: Information from Node $v$ Itself Could Get Lost
#
# - **Problem**:
#     - The computation of $ \mathbf{h}_v^{(l)} $ does not directly depend on $ \mathbf{h}_v^{(l-1)} $.
#     - As a result, information from the node $v$ itself might not be fully represented in the next layer.

# %% [markdown]
# ## Solution: Include $ \mathbf{h}_v^{(l-1)} $ when computing $ \mathbf{h}_v^{(l)} $
#
# ### (1) Message: Compute Message from Node $v$ Itself
# - A separate message computation is performed for the node $v$ itself.
#     - **Equation**: $ \mathbf{m}_u^{(l)} = \mathbf{W}^{(l)} \mathbf{h}_u^{(l-1)} $ for neighboring nodes.
#     - For the node itself:
#         - **Equation**: $ \mathbf{m}_v^{(l)} = \mathbf{B}^{(l)} \mathbf{h}_v^{(l-1)} $
# - This approach ensures that a unique transformation is applied to the node’s own features, separate from those of its neighbors.
#
# ### (2) Aggregation: Aggregate Messages from Neighbors and Node $v$ Itself
# - After aggregating messages from neighbors, include the self-message for node $v$.
#     - This can be done using concatenation or summation.
#     - **Equation**:
#       $$
#       \mathbf{h}_v^{(l)} = \text{CONCAT} \left( \text{AGG} \left( \left\{ \mathbf{m}_u^{(l)}, u \in N(v) \right\} \right), \mathbf{m}_v^{(l)} \right)
#       $$
# - The aggregation first gathers messages from neighbors and then incorporates the message from the node itself for a comprehensive update.

# %% [markdown]
# ## A Single GNN Layer (Summary)
#
# - **(1) Message**: Each node computes a message.
#     - **Equation**: $ \mathbf{m}_u^{(l)} = \text{MSG}^{(l)}\left( \mathbf{h}_u^{(l-1)} \right), \, u \in \{ N(v) \cup v \} $
# - **(2) Aggregation**: Aggregate messages from neighbors.
#     - **Equation**: $ \mathbf{h}_v^{(l)} = \text{AGG}^{(l)}\left( \left\{ \mathbf{m}_u^{(l)}, \, u \in N(v) \right\}, \mathbf{m}_v^{(l)} \right) $
# - **Nonlinearity (Activation)**: Adds expressiveness.
#     - Often written as $ \sigma(\cdot) $. Examples: $ \text{ReLU}(\cdot) $, $ \text{Sigmoid}(\cdot) $, ...
#     - Can be applied to either the message or aggregation step.

# %% [markdown]
# # GCN: An Example of GNN Layer
#
#
# $$ h_v^{(l)} = \sigma \left( \sum_{u \in N(v)} W^{(l)} \frac{h_u^{(l-1)}}{|N(v)|} \right) $$
#
# - **Message:**
#   - For each neighbor \( u \):
#     $$ m_u^{(l)} = \frac{1}{|N(v)|} W^{(l)} h_u^{(l-1)} $$
#     - *Normalized by node degree* (In the original GCN paper, a slightly different normalization is used)
#
# - **Aggregation:**
#   - **Sum** over messages from neighbors, then apply activation:
#     $$ h_v^{(l)} = \sigma \left( \text{Sum} \left( \{ m_u^{(l)}, u \in N(v) \} \right) \right) $$

# %% [markdown]
# # Classical GNN Layers: GraphSAGE
#
#
# $$ h_v^{(l)} = \sigma \left( W^{(l)} \cdot \text{CONCAT} \left( h_v^{(l-1)}, \text{AGG} \left( \{ h_u^{(l-1)}, \forall u \in N(v) \} \right) \right) \right) $$
#
# - **How to write this as Message + Aggregation?**
#   - **Message** is computed within the $\text{AGG}(\cdot)$ function.
#
# - **Two-stage aggregation:**
#   - **Stage 1**: Aggregate from node neighbors
#     $$ h_{N(v)}^{(l)} \leftarrow \text{AGG} \left( \{ h_u^{(l-1)}, \forall u \in N(v) \} \right) $$
#   - **Stage 2**: Further aggregate over the node itself
#     $$ h_v^{(l)} \leftarrow \sigma \left( W^{(l)} \cdot \text{CONCAT} \left( h_v^{(l-1)}, h_{N(v)}^{(l)} \right) \right) $$

# %% [markdown]
# # Aggregation Methods in GraphSAGE
#
# - **Mean**: Take a weighted average of neighbors
#   - $$ \text{AGG} = \sum_{u \in N(v)} \frac{h_u^{(l-1)}}{|N(v)|} $$
#   - *Aggregation* and *Message computation* are based on averaging.
#
# - **Pool**: Transform neighbor vectors and apply a symmetric vector function like Mean or Max
#   - $$ \text{AGG} = \text{Mean} \left( \{ \text{MLP}(h_u^{(l-1)}), \forall u \in N(v) \} \right) $$
#
# - **Sum**: Sum all neighbor embeddings without averaging
#   - $$ \text{AGG} = \sum_{u \in N(v)} h_u^{(l-1)} $$
#   - *Simple and effective*, often used in cases where neighbor count varies significantly.
#
# - **Attention**: Use attention weights to aggregate neighbors
#   - $$ \text{AGG} = \sum_{u \in N(v)} \alpha_{vu} \cdot h_u^{(l-1)} $$
#   - where $ \alpha_{vu} $ are attention coefficients that determine the importance of each neighbor $ u $ for node $ v $.
#   - Attention mechanisms allow nodes to weigh neighbors differently, which can capture more nuanced relationships.
#
# Each of these aggregation methods provides a different way to handle neighbor information, with **Mean** and **Sum** being simpler, while **Attention** allow for more complex interactions.

# %% [markdown]
# # $ \ell_2 $ Normalization
#
# - **Optional**: Apply $ \ell_2 $ normalization to $ h_v^{(l)} $ at every layer
#   - $$ h_v^{(l)} \leftarrow \frac{h_v^{(l)}}{\| h_v^{(l)} \|_2} \quad \forall v \in V \text{ where } \| u \|_2 = \sqrt{\sum_i u_i^2} \; (\ell_2 \text{-norm}) $$
#
# - **Why normalize?**
#   - Without $ \ell_2 $ normalization, the embedding vectors have different scales ($ \ell_2 $-norm) for vectors.
#   - In some cases (not always), normalization of embeddings results in performance improvement.
#   - After $ \ell_2 $ normalization, all vectors will have the same $ \ell_2 $-norm.

# %% [markdown]
# #  GNN Layers: Graph Attention Networks (GAT)
#
#
# $$ h_v^{(l)} = \sigma \left( \sum_{u \in N(v)} \alpha_{vu} W^{(l)} h_u^{(l-1)} \right) $$
#   - *Attention weights*: $ \alpha_{vu} $ represent the importance of node $ u $'s message to node $ v $.
#
# ### In GCN / GraphSAGE
#
# - $ \alpha_{vu} = \frac{1}{|N(v)|} $ is the **weighting factor** (importance) of node $ u $'s message to node $ v $.
#   - $ \Rightarrow \; \alpha_{vu} $ is defined **explicitly** based on the structural properties of the graph (node degree).
#   - $ \Rightarrow $ All neighbors $ u \in N(v) $ are **equally important** to node $ v $.

# %% [markdown]
# # Graph Attention Networks
#
# $$ h_v^{(l)} = \sigma \left( \sum_{u \in N(v)} \alpha_{vu} W^{(l)} h_u^{(l-1)} \right) $$
#   - *Attention weights*: $ \alpha_{vu} $ represent the importance of node $ u $'s message to node $ v $.
#
# ### Not all node's neighbors are equally important
#
# - **Attention** is inspired by cognitive attention.
# - The **attention** $ \alpha_{vu} $ focuses on the important parts of the input data and fades out the rest.
#   - **Idea**: The neural network should devote more computing power to the small but important part of the data.
#   - Which part of the data is more important depends on the context and is learned through training.

# %% [markdown]
# # Can we do better than simple neighborhood aggregation?
#
# ### Can weighting factors $ \alpha_{vu} $ be learned?
#
# - **Goal**: Specify **arbitrary importance** to different neighbors of each node in the graph.
#
# - **Idea**: Compute embedding $ h_v^{(l)} $ of each node in the graph following an **attention strategy**:
#   - Nodes attend over their neighborhood’s messages.
#   - Implicitly specifying different weights to different nodes in a neighborhood.

# %% [markdown]
# # Graph Attention Mechanism
#
# <p align="center">
#     <img src="./img/gat_1.png" alt="gat_mechanism" width="50%">
# </p>
#
# - Let $ \alpha_{vu} $ be computed as a byproduct of an **attention mechanism** $ a $:
#
#   - **(1)** Let $ a $ compute **attention coefficients** $ e_{vu} $ across pairs of nodes $ u, v $ based on their messages:
#     - $$ e_{vu} = a \left( W^{(l)} h_u^{(l-1)}, W^{(l)} h_v^{(l-1)} \right) $$
#     - $ e_{vu} $ indicates the importance of $ u $'s message to node $ v $.
#
# $$ e_{AB} = a \left( W^{(l)} h_A^{(l-1)}, W^{(l)} h_B^{(l-1)} \right) $$

# %% [markdown]
# # Graph Attention Mechanism
#
#
# <p align="center">
#     <img src="./img/gat_2.png" alt="gat_mechanism" width="50%">
# </p>
#
# - **Normalize** $ e_{vu} $ into the final attention weight $ \alpha_{vu} $:
#   - Use the **softmax function**, so that $ \sum_{u \in N(v)} \alpha_{vu} = 1 $:
#     $$ \alpha_{vu} = \frac{\exp(e_{vu})}{\sum_{k \in N(v)} \exp(e_{vk})} $$
#
# - **Weighted sum** based on the final attention weight $ \alpha_{vu} $:
#   $$ h_v^{(l)} = \sigma \left( \sum_{u \in N(v)} \alpha_{vu} W^{(l)} h_u^{(l-1)} \right) $$
#
# - **Example of Weighted Sum** using $ \alpha_{AB}, \alpha_{AC}, \alpha_{AD} $:
#   $$ h_A^{(l)} = \sigma \left( \alpha_{AB} W^{(l)} h_B^{(l-1)} + \alpha_{AC} W^{(l)} h_C^{(l-1)} + \alpha_{AD} W^{(l)} h_D^{(l-1)} \right) $$

# %% [markdown]
# # Graph Attention Mechanism
#
# <p align="center">
#     <img src="./img/gat_concat.png" alt="gat_mechanism" width="50%">
# </p>
#
# - **What is the form of attention mechanism $ a $?**
#   - The approach is **agnostic** to the choice of $ a $.
#   - For example, use a simple single-layer neural network.
#     - $ a $ can have **trainable parameters** (weights in the linear layer).
#
# $$ e_{AB} = a \left( W^{(l)} h_A^{(l-1)}, W^{(l)} h_B^{(l-1)} \right) = \text{Linear} \left( \text{Concat} \left( W^{(l)} h_A^{(l-1)}, W^{(l)} h_B^{(l-1)} \right) \right) $$
#
# - **Parameters of $ a $ are trained jointly**:
#   - Learn the parameters together with weight matrices (i.e., other parameters of the neural net $ W^{(l)} $) in an end-to-end fashion.

# %% [markdown]
# # Graph Attention Mechanism
#
# - **Multi-head attention**: Stabilizes the learning process of the attention mechanism.
#
# - **Create multiple attention scores** (each replica with a different set of parameters):
#   $$ h_v^{(l)}[1] = \sigma \left( \sum_{u \in N(v)} \alpha_{vu}^1 W^{(l)} h_u^{(l-1)} \right) $$
#   $$ h_v^{(l)}[2] = \sigma \left( \sum_{u \in N(v)} \alpha_{vu}^2 W^{(l)} h_u^{(l-1)} \right) $$
#   $$ h_v^{(l)}[3] = \sigma \left( \sum_{u \in N(v)} \alpha_{vu}^3 W^{(l)} h_u^{(l-1)} \right) $$
#
# - **Outputs are aggregated**:
#   - By concatenation or summation:
#     $$ h_v^{(l)} = \text{AGG}(h_v^{(l)}[1], h_v^{(l)}[2], h_v^{(l)}[3]) $$

# %% [markdown]
# # Graph Attention Mechanism Summary
#
# - **Key benefit**: Allows for (implicitly) specifying **different importance values** ($ \alpha_{vu} $) to different neighbors.
#
# - **Computationally efficient**:
#   - Computation of attentional coefficients can be parallelized across all edges of the graph.
#   - Aggregation may be parallelized across all nodes.
#
# - **Storage efficient**:
#   - Sparse matrix operations do not require more than $ O(V + E) $ entries to be stored.
#   - Fixed number of parameters, irrespective of graph size.
#
# - **Localized**:
#   - Only **attends over local network neighborhoods**.
#
# - **Inductive capability**:
#   - It is a shared **edge-wise mechanism**.
#   - It does not depend on the global graph structure.

# %% [markdown]
# <left><img width=25% src="img/gw_monogram_2c.png"></left>
#
# # Part 3: General Considerations

# %% [markdown]
# # Recap: A Single GNN Layer
#
# ### Putting things together:
#
# 1. **Message**: Each node computes a message
#    $$ \mathbf{m}_u^{(l)} = \text{MSG}^{(l)}\left(\mathbf{h}_u^{(l-1)}\right), \, u \in \{N(v) \cup v\} $$
#
# 2. **Aggregation**: Aggregate messages from neighbors
#    $$ \mathbf{h}_v^{(l)} = \text{AGG}^{(l)}\left(\{\mathbf{m}_u^{(l)}, u \in N(v)\}, \mathbf{m}_v^{(l)}\right) $$
#
# 3. **Nonlinearity (Activation)**: Adds expressiveness
#    - Often written as $$\sigma(\cdot)$$, e.g., ReLU($\cdot$), Sigmoid($\cdot$), etc.
#    - Can be added to **message** or **aggregation**.

# %% [markdown]
# # Consideration 1: GNN Layer Connectivity
#
# ### Deep GNN layer?
#
# - GNNs with deep architectures often suffer from **over-smoothing**, where node embeddings become indistinguishable.
# - This poses a challenge for tasks requiring meaningful differentiation of node features.
#
# **Lesson**: To address this, we can **add skip connections in GNNs**, enabling earlier layer outputs to influence later layers.

# %% [markdown]
# <p align="center">
#     <img src="./img/gnn_skip_connections.png" alt="gnn_skip" width="80%">
# </p>

# %% [markdown]
# # Observation from Over-Smoothing
#
# - **Observation**: Node embeddings computed in earlier GNN layers are often better at differentiating nodes.
# - As the GNN gets deeper, the embeddings across nodes tend to converge, losing their distinctiveness.
#
# ---
#
# # Solution: Add Skip Connections
#
# - **Key idea**: Retain the contributions of earlier layers by **adding shortcuts** between layers.
# - These shortcuts ensure that useful features from shallow layers are passed directly to deeper layers.

# %% [markdown]
# # Consideration: Graph Manipulation
#
# ### Why manipulate graphs in GNNs?
# - Graphs often have incomplete or imperfect structure and features.
# - Effective manipulation improves graph quality for downstream learning tasks.
# - Two key types:
#   1. **Graph Feature Manipulation**
#   2. **Graph Structure Manipulation**

# %% [markdown]
# # Graph Feature Manipulation
#
# ### The Problem:
# - Input graphs may **lack meaningful features** for nodes or edges.

# %% [markdown]
# ### The Solution:
# #### **Feature Augmentation**:
# 1. **Node Features**:
#    - Example features:
#      - **Node degree**: The number of connections a node has.
#      - **Centrality measures**: Betweenness, closeness, or eigenvector centrality.
#      - **Domain-specific embeddings**: Features derived from external data (e.g., text embeddings for a document graph).

# %% [markdown]
# 2. **Edge Features**:
#    - Example features:
#      - **Edge weight**: Represents the strength or capacity of the connection.
#      - **Edge type**: Categorical information such as relationship types in a knowledge graph.
#      - **Distance or similarity**: Spatial distance (e.g., in geographical graphs) or similarity scores (e.g., in recommendation systems).
#
# By augmenting these features, we can enrich the input graph and improve the GNN’s ability to learn meaningful representations.

# %% [markdown]
# # Graph Structure Manipulation
#
# ### Why manipulate graph structure?
# - Graphs may have structural challenges:
#   1. **Too sparse**
#   2. **Too dense**
#   3. **Too large**

# %% [markdown]
# # Sparse Graphs
#
# ### The Problem:
# - The graph is **too sparse**:
#   - Nodes may have insufficient neighbors to aggregate meaningful information.
#
# ### The Solution:
# - **Add virtual nodes or edges**:
#   - Connect isolated or under-connected nodes with additional edges.
#   - Add a global node (virtual node) that interacts with all nodes in the graph.

# %% [markdown]
# # Dense Graphs
#
# ### The Problem:
# - The graph is **too dense**:
#   - Too many neighbors lead to high computational costs.
#   - Aggregation may lose relevance due to excessive inputs.
#
# ### The Solution:
# - **Sample neighbors during message passing**:
#   - Randomly select a subset of neighbors for each node to reduce density.
#   - This maintains computational efficiency while preserving the graph's structure.

# %% [markdown]
# # Large Graphs
#
# ### The Problem:
# - The graph is **too large**:
#   - Storing and processing the entire graph becomes infeasible.
#
# ### The Solution:
# - **Sample subgraphs to compute embeddings**:
#   - Use techniques like mini-batching or subgraph sampling.
#   - Divide the graph into smaller, manageable parts for computation.

# %% [markdown]
# # Different Graph Tasks using GNNs
# <p align="center">
#     <img src="./img/gnn_graph_tasks.png" alt="gnn_tasks" width="80%">
# </p>

# %% [markdown]
# # Prediction Heads: Node-Level
#
# ### **Node-Level Prediction**:
# - We can directly make predictions using node embeddings!
# - After GNN computation, each node is represented as a **d-dimensional embedding**:
#   $$ \{\mathbf{h}_v^{(L)} \in \mathbb{R}^d, \forall v \in G\} $$
#
# ---
#
# ### Why is this important?
# - These embeddings contain rich, learned information about the node's local and global graph context.
# - They serve as input to a **prediction head** for node-specific tasks.

# %% [markdown]
# # Prediction Heads: Node-Level
#
# ### **Node-Level Prediction**:
# - We can directly make predictions using node embeddings!
# - After GNN computation, each node is represented as a **d-dimensional embedding**:
#   $$ \{\mathbf{h}_v^{(L)} \in \mathbb{R}^d, \forall v \in G\} $$
#
#
# ### Why is this important?
# - These embeddings contain rich, learned information about the node's local and global graph context.
# - They serve as input to a **prediction head** for node-specific tasks.

# %% [markdown]
# # Prediction Tasks at the Node Level
#
# ### Suppose we want to make **k-way predictions**:
#
# 1. **Classification**:
#    - Assign each node to one of *k* categories.
#    - Example: Predict node types in a molecule graph (e.g., carbon, oxygen).
#
# 2. **Regression**:
#    - Predict *k* target values for each node.
#    - Example: Predict traffic congestion at road network nodes.
#
# ---
#
# ### Output of the Prediction Head:
# - For each node, the model produces:
#   $$ \hat{\mathbf{y}}_v \in \mathbb{R}^k $$
#   - **Classification**: $\hat{\mathbf{y}}_v$ represents probabilities over *k* classes.
#   - **Regression**: $\hat{\mathbf{y}}_v$ contains *k* continuous target values.

# %% [markdown]
# # Prediction Head: Mapping Embeddings to Predictions
#
# ### The Prediction Formula:
# - The prediction head maps the final node embedding $\mathbf{h}_v^{(L)}$ to the prediction $\hat{\mathbf{y}}_v$:
#   $$ \hat{\mathbf{y}}_v = \mathbf{W}^{(H)} \mathbf{h}_v^{(L)} $$
#
# ---
#
# ### Components:
# 1. $\mathbf{h}_v^{(L)}$: Node embedding from the final GNN layer, $\in \mathbb{R}^d$.
# 2. $\mathbf{W}^{(H)} \in \mathbb{R}^{k \times d}$:
#    - Weight matrix for the prediction head.
#    - Maps embeddings from $\mathbb{R}^d$ to $\mathbb{R}^k$.
#
# ---
#
# ### Key Idea:
# - The weight matrix $\mathbf{W}^{(H)}$ learns how to project the high-dimensional embedding into a space suitable for the prediction task.

# %% [markdown]
# # Loss Computation and Training
#
#
# ### Example Loss Functions:
# 1. **Classification**:
#    - Use cross-entropy loss for *k* categories.
#    - Interpret $\hat{\mathbf{y}}_v$ as probabilities after applying softmax.
#
# 2. **Regression**:
#    - Use mean squared error (MSE) for *k* continuous values.
#    - $\hat{\mathbf{y}}_v$ directly represents predictions.
#
# ### Training Goal:
# - Adjust GNN and prediction head weights ($\mathbf{W}^{(H)}$) to minimize the task-specific loss.

# %% [markdown]
# # Prediction Heads: Edge-Level
#
# ### What is Edge-Level Prediction?
# - **Edge-level prediction** involves making predictions about the relationships between **pairs of nodes**.
# - This utilizes the embeddings of the two nodes connected by the edge.
#
# ---
#
# ### Applications:
# - **Link Prediction**: Predict whether a connection (edge) exists between two nodes.
# - **Edge Classification**: Categorize the type or nature of an edge (e.g., friendship, professional, etc.).

# %% [markdown]
# # Example of Edge-Level Prediction
#
# ### Problem:
# - In the graph below, predict the edge label (e.g., connection type) for the edge between nodes $u$ and $v$.
#
# ### Workflow:
# 1. Obtain $\mathbf{h}_u^{(L)}$ and $\mathbf{h}_v^{(L)}$ from the GNN.
# 2. Use $\text{Head}_{\text{edge}}$ to combine the embeddings.
# 3. Compute the prediction $\hat{y}_{uv}$.
#
# <p align="center">
#     <img src="./img/gnn_edge_level.png" alt="gnn_edge_level" width="50%">
# </p>

# %% [markdown]
# # Prediction Head for Edge-Level Tasks
#
#
# ### The Prediction Formula:
# - To make a prediction for an edge $(u, v)$:
#   $$ \hat{y}_{uv} = \text{Head}_{\text{edge}}(\mathbf{h}_u^{(L)}, \mathbf{h}_v^{(L)}) $$
#
#
#
# ### Components:
# 1. $\mathbf{h}_u^{(L)}$: Embedding of node $u$ from the final GNN layer.
# 2. $\mathbf{h}_v^{(L)}$: Embedding of node $v$ from the final GNN layer.
# 3. $\text{Head}_{\text{edge}}$: A function that combines the embeddings of $u$ and $v$ to produce the edge prediction $\hat{y}_{uv}$.

# %% [markdown]
# # Options for $\text{Head}_{\text{edge}}$
#
# ### How can we combine $\mathbf{h}_u^{(L)}$ and $\mathbf{h}_v^{(L)}$?
#
# 1. **Concatenation**:
#    - Combine the embeddings by concatenating them:
#      $$ \text{Head}_{\text{edge}}(\mathbf{h}_u^{(L)}, \mathbf{h}_v^{(L)}) = \mathbf{W} [\mathbf{h}_u^{(L)} \| \mathbf{h}_v^{(L)}] $$
#    - This allows the model to learn from the combined information.
#
# 2. **Dot Product**:
#    - Use the similarity of the two embeddings:
#      $$ \text{Head}_{\text{edge}}(\mathbf{h}_u^{(L)}, \mathbf{h}_v^{(L)}) = \mathbf{h}_u^{(L)} \cdot \mathbf{h}_v^{(L)} $$
#
# 3. **Element-wise Operations**:
#    - Perform operations like addition, subtraction, or multiplication:
#      $$ \text{Head}_{\text{edge}}(\mathbf{h}_u^{(L)}, \mathbf{h}_v^{(L)}) = \mathbf{h}_u^{(L)} \odot \mathbf{h}_v^{(L)} $$
#
# 4. **MLP**:
#    - Pass the embeddings through a Multi-Layer Perceptron (MLP):
#      $$ \text{Head}_{\text{edge}}(\mathbf{h}_u^{(L)}, \mathbf{h}_v^{(L)}) = \text{MLP}([\mathbf{h}_u^{(L)} \| \mathbf{h}_v^{(L)}]) $$

# %% [markdown]
# # Prediction Heads: Graph-Level
#
# ### What is Graph-Level Prediction?
# - **Graph-level prediction** involves making predictions using the embeddings of **all nodes in the graph**.
# - Example Applications:
#   - Predicting the **function** of a molecular graph (e.g., toxic vs. non-toxic).
#   - Predicting properties of social networks (e.g., community engagement).
#
# ---
#
# ### After GNN Computation:
# - The graph is represented by the set of node embeddings:
#   $$ \{\mathbf{h}_v^{(L)} \in \mathbb{R}^d, \forall v \in G\} $$
# - These embeddings are aggregated to form a graph-level embedding.

# %% [markdown]
# # Graph-Level Prediction Head
#
# ### Making Predictions:
# - For a graph $G$, the prediction is:
#   $$ \hat{\mathbf{y}}_G = \text{Head}_{\text{graph}}(\{\mathbf{h}_v^{(L)} \in \mathbb{R}^d, \forall v \in G\}) $$
#
# ---
#
# ### Key Steps:
# 1. **Aggregation**: Combine the node embeddings into a single graph-level embedding.
#    - Example methods: mean pooling, max pooling, or attention.
# 2. **Prediction**: Use the aggregated embedding for $k$-way predictions:
#    - **Classification**: Predict among $k$ categories.
#    - **Regression**: Predict $k$ continuous properties.

# %% [markdown]
# # Aggregation Methods for Graph-Level Prediction
#
# ### How to Aggregate Node Embeddings?
#
# 1. **Mean Pooling**:
#    - Compute the average of all node embeddings:
#      $$ \mathbf{h}_G = \frac{1}{|G|} \sum_{v \in G} \mathbf{h}_v^{(L)} $$
#
# 2. **Max Pooling**:
#    - Take the element-wise maximum across all node embeddings:
#      $$ \mathbf{h}_G = \text{max}(\{\mathbf{h}_v^{(L)}\}) $$
#
# 3. **Attention-Based Pooling**:
#    - Weight each node embedding by its importance:
#      $$ \mathbf{h}_G = \sum_{v \in G} \alpha_v \mathbf{h}_v^{(L)} $$
#      - $\alpha_v$: Learnable attention score for node $v$.

# %% [markdown]
# # Issue of Global Pooling
#
# ### **Problem**:
# - Global pooling over a (large) graph can lose crucial information about the structure of the graph.
#
# ---
#
# ### **Toy Example**:
# - Consider a simple case where nodes have **1-dimensional embeddings**:
#
# 1. **Node embeddings for Graph $G_1$**:
#    $$ \{-1, -2, 0, 1, 2\} $$
#
# 2. **Node embeddings for Graph $G_2$**:
#    $$ \{-10, -20, 0, 10, 20\} $$
#
# ---
#
# ### Observation:
# - Clearly, $G_1$ and $G_2$ have very different node embeddings.
#   - **Their structures should also be different**.

# %% [markdown]
# # Hierarchical Global Pooling
#
# ### **What is Hierarchical Global Pooling?**
# - A pooling method that **preserves graph structure** by iteratively aggregating information at multiple levels of granularity.
# - Instead of a single global aggregation, it uses **local subgraph pooling** followed by higher-level pooling.
#
# ---
#
# ### **How It Works**:
# 1. **Partition the Graph**:
#    - Divide the graph into smaller subgraphs (e.g., using clustering or community detection).
#
# 2. **Local Aggregation**:
#    - Pool node embeddings **within each subgraph** to create subgraph-level embeddings.
#
# 3. **Hierarchical Aggregation**:
#    - Treat subgraphs as "super-nodes" in a coarser graph and perform global pooling.

# %% [markdown]
# ### **Advantages**:
# 1. **Preserves Structure**:
#    - Maintains hierarchical relationships between nodes and subgraphs.
# 2. **Improves Differentiation**:
#    - Captures structural nuances of the graph by aggregating progressively.
# 3. **Flexibility**:
#    - Can use various pooling methods (e.g., mean, max, attention) at each level.
#
# ---
#
# ### **Example**:
# - In a molecular graph:
#   - Partition by functional groups.
#   - Pool embeddings for nodes in each group.
#   - Aggregate group embeddings for a final molecular representation.

# %% [markdown]
# <p align="center">
#     <img src="./img/hierarchical_pooling.png" alt="hierarchical_pooling" width="100%">
# </p>

# %% [markdown]
# # Where Does Ground-Truth (Labels) Come From?
#
# <p align="center">
#     <img src="./img/training_pipeline.png" alt="training_pipeline" width="100%">
# </p>
#
#
# ### Ground-Truth Sources:
# - **Supervised Labels**:
#   - Labels provided for the task (e.g., node labels for classification, edge labels for link prediction).
#   - Directly used to compute the loss.
#
# - **Unsupervised Signals**:
#   - Signals derived from the graph structure (e.g., proximity, connectivity).
#   - Used for tasks like node embedding pretraining or link prediction.

# %% [markdown]
# # Supervised vs Unsupervised Learning on Graphs
#
# ### **Supervised Learning on Graphs**:
# - **Labels come from external sources**:
#   - Example: Predict whether a molecular graph represents a drug (drug-likeness prediction).
# - **Uses explicit labeled data**:
#   - Tasks like classification (node, edge, or graph level).

# %% [markdown]
# ### **Unsupervised Learning on Graphs**:
# - **Signals come from the graph itself**:
#   - Example: Predict if two nodes are connected (**link prediction**).
# - **No explicit labels provided**:
#   - Relies on structural information or intrinsic graph properties.

# %% [markdown]
# ### **Blurry Boundaries**:
# - The distinction between supervised and unsupervised learning can sometimes be unclear:
#   1. **Supervision in Unsupervised Learning**:
#      - Example: Train a GNN to predict a **node clustering coefficient**, which is derived from the graph.
#   2. **Self-Supervised Learning**:
#      - An alternative term for "unsupervised" learning, where the graph itself provides the learning signal.

# %% [markdown]
# # Supervised Labels on Graphs
#
# ### **Where Do Supervised Labels Come From?**
# - **Supervised labels** are derived from specific use cases.
#   Examples include:
#
# 1. **Node Labels ($y_v$)**:
#    - Example: In a **citation network**, determine the subject area a node (paper) belongs to.
#
# 2. **Edge Labels ($y_{uv}$)**:
#    - Example: In a **transaction network**, identify whether an edge (transaction) is fraudulent.
#
# 3. **Graph Labels ($y_G$)**:
#    - Example: In **molecular graphs**, predict if the graph represents a drug-like compound.
#
# ---
#
# ### **Advice**:
# - Reduce your task to **node**, **edge**, or **graph** labels whenever possible.
#   - These tasks are easier to model and train.
#
# ---
#
# ### **Example**:
# - If we know some nodes form a cluster, we can treat this as a **node labeling task**:
#   - Assign a label to each node indicating the cluster it belongs to.

# %% [markdown]
# # Unsupervised Signals on Graphs
#
# ### **The Problem**:
# - Sometimes, we only have a graph **without any external labels**.
#
# ---
#
# ### **The Solution**:
# - Use **self-supervised learning** to find supervision signals **within the graph itself**.
#
# ---
#
# ### **Example Tasks**:
# - Let the GNN predict the following:
#
# 1. **Node-Level ($y_v$)**:
#    - Predict intrinsic **node statistics** such as:
#      - Clustering coefficient.
#      - PageRank score.
#      - Node degree.
#
# 2. **Edge-Level ($y_{uv}$)**:
#    - Perform **link prediction**:
#      - Hide edges between nodes and predict whether an edge should exist.
#
# 3. **Graph-Level ($y_G$)**:
#    - Predict **graph statistics**, such as:
#      - Determine if two graphs are **isomorphic** (structurally identical).
#
# ---
#
# ### **Key Insight**:
# - **These tasks do not require any external labels!**
#   - The graph itself provides all the necessary signals for training.
